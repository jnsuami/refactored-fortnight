# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Jason Nsuami</b>

# %% [markdown]
# Data Scientist

# %% [markdown]
# *I am interested in data scientist because I have always had a fascination with working with data and statistics. I would love to turn my love and data, numbers, and statistics into a long-lasting career where I can benefit companies and businesses.*

# %% [markdown]
# ### My code will add 1+1

# %%
print(1+1)
# Out:
# 2

# %% [markdown]
# 1. January
# 2. February
# 3. March

# %% [markdown]
# - head
# - shoulders
# - knees
# - toes

# %% [markdown]
# ![242523785_206310581504237_1131974288421973947_n.jpg](attachment:242523785_206310581504237_1131974288421973947_n.jpg)
